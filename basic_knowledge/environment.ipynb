# %% [markdown]
# # test the python version and installed packages

# %%
import sys
print(sys.version)

import pip
packages = sorted(["%s==%s" % (i.key, i.version) for i in pip.get_installed_distributions()])
for i in range(len(packages)):
    print(i,':', packages[i])
# Out:
# 3.6.5 (default, Apr  4 2018, 16:37:47)
# [GCC 4.8.5 20150623 (Red Hat 4.8.5-16)]
# 0 : absl-py==0.2.2
# 1 : astor==0.7.1
# 2 : backcall==0.1.0
# 3 : bitarray==0.8.3
# 4 : bleach==1.5.0
# 5 : certifi==2018.11.29
# 6 : chardet==3.0.4
# 7 : cycler==0.10.0
# 8 : cython==0.28.1
# 9 : decorator==4.2.1
# 10 : defusedxml==0.5.0
# 11 : django==2.1.5
# 12 : entrypoints==0.3
# 13 : gast==0.2.0
# 14 : grpcio==1.13.0
# 15 : hmmlearn==0.2.0
# 16 : html5lib==0.9999999
# 17 : idna==2.8
# 18 : ipykernel==5.1.0
# 19 : ipython-genutils==0.2.0
# 20 : ipython==6.3.0
# 21 : ipywidgets==7.4.2
# 22 : jedi==0.11.1
# 23 : jinja2==2.10
# 24 : joblib==0.11
# 25 : jsonschema==2.6.0
# 26 : jupyter-client==5.2.4
# 27 : jupyter-console==6.0.0
# 28 : jupyter-contrib-core==0.3.3
# 29 : jupyter-contrib-nbextensions==0.5.1
# 30 : jupyter-core==4.4.0
# 31 : jupyter-highlight-selected-word==0.2.0
# 32 : jupyter-latex-envs==1.4.6
# 33 : jupyter-nbextensions-configurator==0.4.1
# 34 : jupyter==1.0.0
# 35 : justext==2.2.0
# 36 : kiwisolver==1.0.1
# 37 : lazynlp==0.0.1
# 38 : lxml==4.3.2
# 39 : markdown==2.6.11
# 40 : markupsafe==1.1.0
# 41 : matplotlib==2.2.2
# 42 : mistune==0.8.4
# 43 : nbconvert==5.4.1
# 44 : nbformat==4.4.0
# 45 : networkit==4.5
# 46 : networkx==2.1
# 47 : nose==1.3.7
# 48 : notebook==5.7.4
# 49 : numpy==1.14.2
# 50 : pandas==0.22.0
# 51 : pandocfilters==1.4.2
# 52 : parso==0.1.1
# 53 : patsy==0.5.1
# 54 : pexpect==4.4.0
# 55 : pickleshare==0.7.4
# 56 : pip==9.0.3
# 57 : prometheus-client==0.6.0
# 58 : prompt-toolkit==1.0.15
# 59 : protobuf==3.6.0
# 60 : ptyprocess==0.5.2
# 61 : pybloom==2.0.0
# 62 : pygments==2.2.0
# 63 : pyparsing==2.2.0
# 64 : python-dateutil==2.7.2
# 65 : pytz==2018.3
# 66 : pyyaml==3.13
# 67 : pyzmq==18.0.0
# 68 : qtconsole==4.4.3
# 69 : requests-file==1.4.3
# 70 : requests==2.21.0
# 71 : scikit-learn==0.19.1
# 72 : scikit-surprise==1.0.6
# 73 : scipy==1.0.1
# 74 : seaborn==0.8.1
# 75 : send2trash==1.5.0
# 76 : setuptools==39.0.1
# 77 : simplegeneric==0.8.1
# 78 : six==1.11.0
# 79 : sklearn==0.0
# 80 : statsmodels==0.9.0
# 81 : tabulate==0.8.2
# 82 : tensorboard==1.8.0
# 83 : tensorflow==1.8.0
# 84 : termcolor==1.1.0
# 85 : terminado==0.8.1
# 86 : testpath==0.4.2
# 87 : tldextract==2.2.0
# 88 : tornado==5.1.1
# 89 : traitlets==4.3.2
# 90 : unidecode==1.0.23
# 91 : urllib3==1.24.1
# 92 : wcwidth==0.1.7
# 93 : webencodings==0.5.1
# 94 : werkzeug==0.14.1
# 95 : wheel==0.31.1
# 96 : widgetsnbextension==3.4.2
